# %%
import numpy as np
import pydensecrf.densecrf as dcrf
import matplotlib.pyplot as plt
from pydensecrf.utils import unary_from_labels, create_pairwise_bilateral, create_pairwise_gaussian
import cv2
from skimage.color import gray2rgb
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
from osgeo import gdal
import os
# %matplotlib inline

# %%
mask_path = '/data1/ian/share_code/result_mask_new1/'
WSI_path = '/data1/ian/C16_training_small/testing'
files = os.listdir(mask_path)
for f in files:
    if 'probas' in f:
        print(f)
        mask = os.path.join(mask_path, f)  
        y = cv2.imread(mask)
        WSI = os.path.join(WSI_path,f[:-11] + '.png')
        print(WSI)
        X=cv2.imread(WSI)
        x_size = X.size
        y_size = y.size

        X = cv2.resize(X, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
        y = cv2.resize(y, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
# Out:
# test_022_probas.png
# /data1/ian/C16_training_small/testing/test_022.png
# test_119_probas.png
# /data1/ian/C16_training_small/testing/test_119.png
# test_092_probas.png
# /data1/ian/C16_training_small/testing/test_092.png
# test_124_probas.png
# /data1/ian/C16_training_small/testing/test_124.png
# test_123_probas.png
# /data1/ian/C16_training_small/testing/test_123.png
# test_015_probas.png
# /data1/ian/C16_training_small/testing/test_015.png
# test_063_probas.png
# /data1/ian/C16_training_small/testing/test_063.png
# test_034_probas.png
# /data1/ian/C16_training_small/testing/test_034.png
# test_072_probas.png
# /data1/ian/C16_training_small/testing/test_072.png
# test_101_probas.png
# /data1/ian/C16_training_small/testing/test_101.png
# test_007_probas.png
# /data1/ian/C16_training_small/testing/test_007.png
# test_058_probas.png
# /data1/ian/C16_training_small/testing/test_058.png
# test_094_probas.png
# /data1/ian/C16_training_small/testing/test_094.png
# test_026_probas.png
# /data1/ian/C16_training_small/testing/test_026.png
# test_064_probas.png
# /data1/ian/C16_training_small/testing/test_064.png
# test_106_probas.png
# /data1/ian/C16_training_small/testing/test_106.png
# test_096_probas.png
# /data1/ian/C16_training_small/testing/test_096.png
# test_037_probas.png
# /data1/ian/C16_training_small/testing/test_037.png
# test_025_probas.png
# /data1/ian/C16_training_small/testing/test_025.png
# test_039_probas.png
# /data1/ian/C16_training_small/testing/test_039.png
# test_102_probas.png
# /data1/ian/C16_training_small/testing/test_102.png
# test_117_probas.png
# /data1/ian/C16_training_small/testing/test_117.png
# test_086_probas.png
# /data1/ian/C16_training_small/testing/test_086.png
# test_066_probas.png
# /data1/ian/C16_training_small/testing/test_066.png
# test_095_probas.png
# /data1/ian/C16_training_small/testing/test_095.png
# test_098_probas.png
# /data1/ian/C16_training_small/testing/test_098.png
# test_027_probas.png
# /data1/ian/C16_training_small/testing/test_027.png
# test_084_probas.png
# /data1/ian/C16_training_small/testing/test_084.png
# test_085_probas.png
# /data1/ian/C16_training_small/testing/test_085.png
# test_069_probas.png
# /data1/ian/C16_training_small/testing/test_069.png
# test_030_probas.png
# /data1/ian/C16_training_small/testing/test_030.png
# test_016_probas.png
# /data1/ian/C16_training_small/testing/test_016.png
# test_070_probas.png
# /data1/ian/C16_training_small/testing/test_070.png
# test_099_probas.png
# /data1/ian/C16_training_small/testing/test_099.png
# test_081_probas.png
# /data1/ian/C16_training_small/testing/test_081.png
# test_047_probas.png
# /data1/ian/C16_training_small/testing/test_047.png
# test_048_probas.png
# /data1/ian/C16_training_small/testing/test_048.png
# test_031_probas.png
# /data1/ian/C16_training_small/testing/test_031.png
# test_043_probas.png
# /data1/ian/C16_training_small/testing/test_043.png
# test_121_probas.png
# /data1/ian/C16_training_small/testing/test_121.png
# test_004_probas.png
# /data1/ian/C16_training_small/testing/test_004.png
# test_089_probas.png
# /data1/ian/C16_training_small/testing/test_089.png
# test_079_probas.png
# /data1/ian/C16_training_small/testing/test_079.png
# test_050_probas.png
# /data1/ian/C16_training_small/testing/test_050.png
# test_008_probas.png
# /data1/ian/C16_training_small/testing/test_008.png
# test_107_probas.png
# /data1/ian/C16_training_small/testing/test_107.png
# test_045_probas.png
# /data1/ian/C16_training_small/testing/test_045.png
# test_044_probas.png
# /data1/ian/C16_training_small/testing/test_044.png
# test_120_probas.png
# /data1/ian/C16_training_small/testing/test_120.png
# test_074_probas.png
# /data1/ian/C16_training_small/testing/test_074.png
# test_024_probas.png
# /data1/ian/C16_training_small/testing/test_024.png
# test_023_probas.png
# /data1/ian/C16_training_small/testing/test_023.png
# test_129_probas.png
# /data1/ian/C16_training_small/testing/test_129.png
# test_128_probas.png
# /data1/ian/C16_training_small/testing/test_128.png
# test_114_probas.png
# /data1/ian/C16_training_small/testing/test_114.png
# test_005_probas.png
# /data1/ian/C16_training_small/testing/test_005.png
# test_032_probas.png
# /data1/ian/C16_training_small/testing/test_032.png
# test_035_probas.png
# /data1/ian/C16_training_small/testing/test_035.png
# test_127_probas.png
# /data1/ian/C16_training_small/testing/test_127.png
# test_011_probas.png
# /data1/ian/C16_training_small/testing/test_011.png
# test_083_probas.png
# /data1/ian/C16_training_small/testing/test_083.png
# test_105_probas.png
# /data1/ian/C16_training_small/testing/test_105.png
# test_088_probas.png
# /data1/ian/C16_training_small/testing/test_088.png
# test_056_probas.png
# /data1/ian/C16_training_small/testing/test_056.png
# test_111_probas.png
# /data1/ian/C16_training_small/testing/test_111.png
# test_028_probas.png
# /data1/ian/C16_training_small/testing/test_028.png
# test_075_probas.png
# /data1/ian/C16_training_small/testing/test_075.png
# test_071_probas.png
# /data1/ian/C16_training_small/testing/test_071.png
# test_080_probas.png
# /data1/ian/C16_training_small/testing/test_080.png
# test_104_probas.png
# /data1/ian/C16_training_small/testing/test_104.png
# test_053_probas.png
# /data1/ian/C16_training_small/testing/test_053.png
# test_118_probas.png
# /data1/ian/C16_training_small/testing/test_118.png
# test_116_probas.png
# /data1/ian/C16_training_small/testing/test_116.png
# test_076_probas.png
# /data1/ian/C16_training_small/testing/test_076.png
# test_122_probas.png
# /data1/ian/C16_training_small/testing/test_122.png
# test_009_probas.png
# /data1/ian/C16_training_small/testing/test_009.png
# test_067_probas.png
# /data1/ian/C16_training_small/testing/test_067.png
# test_002_probas.png
# /data1/ian/C16_training_small/testing/test_002.png
# test_061_probas.png
# /data1/ian/C16_training_small/testing/test_061.png
# test_082_probas.png
# /data1/ian/C16_training_small/testing/test_082.png
# test_097_probas.png
# /data1/ian/C16_training_small/testing/test_097.png
# test_073_probas.png
# /data1/ian/C16_training_small/testing/test_073.png
# test_087_probas.png
# /data1/ian/C16_training_small/testing/test_087.png
# test_012_probas.png
# /data1/ian/C16_training_small/testing/test_012.png
# test_093_probas.png
# /data1/ian/C16_training_small/testing/test_093.png
# test_077_probas.png
# /data1/ian/C16_training_small/testing/test_077.png
# test_054_probas.png
# /data1/ian/C16_training_small/testing/test_054.png
# test_019_probas.png
# /data1/ian/C16_training_small/testing/test_019.png
# test_110_probas.png
# /data1/ian/C16_training_small/testing/test_110.png
# test_108_probas.png
# /data1/ian/C16_training_small/testing/test_108.png
# test_014_probas.png
# /data1/ian/C16_training_small/testing/test_014.png
# test_042_probas.png
# /data1/ian/C16_training_small/testing/test_042.png
# test_068_probas.png
# /data1/ian/C16_training_small/testing/test_068.png
# test_003_probas.png
# /data1/ian/C16_training_small/testing/test_003.png
# test_060_probas.png
# /data1/ian/C16_training_small/testing/test_060.png
# test_059_probas.png
# /data1/ian/C16_training_small/testing/test_059.png
# test_078_probas.png
# /data1/ian/C16_training_small/testing/test_078.png
# test_020_probas.png
# /data1/ian/C16_training_small/testing/test_020.png
# test_001_probas.png
# /data1/ian/C16_training_small/testing/test_001.png
# test_052_probas.png
# /data1/ian/C16_training_small/testing/test_052.png
# test_038_probas.png
# /data1/ian/C16_training_small/testing/test_038.png
# test_113_probas.png
# /data1/ian/C16_training_small/testing/test_113.png
# test_033_probas.png
# /data1/ian/C16_training_small/testing/test_033.png
# test_046_probas.png
# /data1/ian/C16_training_small/testing/test_046.png
# test_017_probas.png
# /data1/ian/C16_training_small/testing/test_017.png
# test_091_probas.png
# /data1/ian/C16_training_small/testing/test_091.png
# test_126_probas.png
# /data1/ian/C16_training_small/testing/test_126.png
# test_010_probas.png
# /data1/ian/C16_training_small/testing/test_010.png
# test_100_probas.png
# /data1/ian/C16_training_small/testing/test_100.png
# test_018_probas.png
# /data1/ian/C16_training_small/testing/test_018.png
# test_103_probas.png
# /data1/ian/C16_training_small/testing/test_103.png
# test_057_probas.png
# /data1/ian/C16_training_small/testing/test_057.png
# test_041_probas.png
# /data1/ian/C16_training_small/testing/test_041.png
# test_065_probas.png
# /data1/ian/C16_training_small/testing/test_065.png
# test_036_probas.png
# /data1/ian/C16_training_small/testing/test_036.png
# test_013_probas.png
# /data1/ian/C16_training_small/testing/test_013.png
# test_062_probas.png
# /data1/ian/C16_training_small/testing/test_062.png
# test_029_probas.png
# /data1/ian/C16_training_small/testing/test_029.png
# test_055_probas.png
# /data1/ian/C16_training_small/testing/test_055.png
# test_006_probas.png
# /data1/ian/C16_training_small/testing/test_006.png
# test_109_probas.png
# /data1/ian/C16_training_small/testing/test_109.png
# test_040_probas.png
# /data1/ian/C16_training_small/testing/test_040.png
# test_051_probas.png
# /data1/ian/C16_training_small/testing/test_051.png
# test_090_probas.png
# /data1/ian/C16_training_small/testing/test_090.png
# test_021_probas.png
# /data1/ian/C16_training_small/testing/test_021.png
# test_125_probas.png
# /data1/ian/C16_training_small/testing/test_125.png
# test_115_probas.png
# /data1/ian/C16_training_small/testing/test_115.png
# test_112_probas.png
# /data1/ian/C16_training_small/testing/test_112.png

# %%
"""
Function which returns the labelled image after applying CRF

"""

#Original_image = Image which has to labelled
#Annotated image = Which has been labelled by some technique( FCN in this case)
#Output_image = Name of the final output image after applying CRF
#Use_2d = boolean variable 
#if use_2d = True specialised 2D fucntions will be applied
#else Generic functions will be applied

def crf(original_image, annotated_image, use_2d = True):
    
    # Converting annotated image to RGB if it is Gray scale
    if(len(annotated_image.shape)<3):
        annotated_image = gray2rgb(annotated_image).astype(np.uint32)
    
    cv2.imwrite("testing2.png",annotated_image)
    annotated_image = annotated_image.astype(np.uint32)
    #Converting the annotations RGB color to single 32 bit integer
    annotated_label = annotated_image[:,:,0].astype(np.uint32) + (annotated_image[:,:,1]<<8).astype(np.uint32) + (annotated_image[:,:,2]<<16).astype(np.uint32)
    
    # Convert the 32bit integer color to 0,1, 2, ... labels.
    colors, labels = np.unique(annotated_label, return_inverse=True)
    
    #Creating a mapping back to 32 bit colors
    colorize = np.empty((len(colors), 3), np.uint8)
    colorize[:,0] = (colors & 0x0000FF)
    colorize[:,1] = (colors & 0x00FF00) >> 8
    colorize[:,2] = (colors & 0xFF0000) >> 16
    
    #Gives no of class labels in the annotated image
    n_labels = len(set(labels.flat)) 
    
    print("No of labels in the Image are ")
    print(n_labels)
    
    
    #Setting up the CRF model
    if use_2d :
        d = dcrf.DenseCRF2D(original_image.shape[1], original_image.shape[0], n_labels)

        # get unary potentials (neg log probability)
        U = unary_from_labels(labels, n_labels, gt_prob=0.90, zero_unsure=False)
        d.setUnaryEnergy(U)

        # This adds the color-independent term, features are the locations only.
        d.addPairwiseGaussian(sxy=(3, 3), compat=3, kernel=dcrf.DIAG_KERNEL,
                          normalization=dcrf.NORMALIZE_SYMMETRIC)

        # This adds the color-dependent term, i.e. features are (x,y,r,g,b).
        d.addPairwiseBilateral(sxy=(80, 80), srgb=(13, 13, 13), rgbim=original_image,
                           compat=10,
                           kernel=dcrf.DIAG_KERNEL,
                           normalization=dcrf.NORMALIZE_SYMMETRIC)
        
    #Run Inference for 5 steps 
    Q = d.inference(5)

    # Find out the most probable class for each pixel.
    MAP = np.argmax(Q, axis=0)

    # Convert the MAP (labels) back to the corresponding colors and save the image.
    # Note that there is no "unknown" here anymore, no matter what we had at first.
    MAP = colorize[MAP,:]
    #cv2.imwrite(output_image,MAP.reshape(original_image.shape))
    return MAP.reshape(original_image.shape)

# %%
crfimage = crf(X,y,"out.png")
# Out:
# No of labels in the Image are
# 256

# %%
plt.subplot(1,2,1)
plt.imshow(y)
plt.subplot(1,2,2)
plt.imshow(crfimage)
